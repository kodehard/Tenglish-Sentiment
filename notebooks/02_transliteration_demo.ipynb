# %% [markdown]
# # 02 — Transliteration Demo: Roman Tenglish → Telugu Script
#
# Demonstrate IndicXlit transliteration on sample Tenglish sentences.

# %%
import sys
sys.path.insert(0, "../src")

from transliterate import transliterate_batch

# %% [markdown]
# ## Sample Transliterations

# %%
samples = [
    "movie chala bagundi bro",
    "acting assalu nachaledu",
    "story ok ok undi",
    "I love this film",
    "naku em kanipistundi",
    "ばかやろう",  # Japanese — should pass through
]

telugu_texts = transliterate_batch(samples)

print(f"{'Roman Tenglish':<35} | {'Telugu Script'}")
print("-" * 70)
for roman, telugu in zip(samples, telugu_texts):
    print(f"{roman:<35} | {telugu}")
# Out:
# Roman Tenglish                      | Telugu Script
# ----------------------------------------------------------------------
# movie chala bagundi bro             | మొవిఎ చల బగున్ది బ్రొ
# acting assalu nachaledu             | అచ్తిన్గ్ అస్సలు నచలెదు
# story ok ok undi                    | స్తొర్య్ ఒక్ ఒక్ ఉన్ది
# I love this film                    | ఈ లొవె థిస్ fిల్మ్
# naku em kanipistundi                | నకు ఎమ్ కనిపిస్తున్ది
# ばかやろう                               | ばかやろう
